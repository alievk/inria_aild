# %%
import cv2
import numpy as np

import os
from pathlib import Path

# %%
pjoin = os.path.join

# %%
root = '/home/kaliev/Downloads/AerialImageDataset'
crop_root = '/home/kaliev/Downloads/AerialImageDataset_crop'

# %%
# !mkdir -p {crop_root}/train/gt
# !mkdir -p {crop_root}/train/images

# %%
flist = [x for x in Path(Path(root) / 'train').glob('**/**/*tif')]
assert len(flist) == 360
for fpath in flist:
    img = cv2.imread(str(fpath))
    assert img.shape == (5000, 5000, 3)
    parts = []
    for i in range(16):
        x = (i % 4) * 1250
        y = (i // 4) * 1250
        crop = img[y:y+1250,x:x+1250,:]
        out_path = Path(crop_root) / pjoin(*fpath.parts[-3:-1]) / (fpath.stem + f'-{i}.tif')
        print(out_path)
        cv2.imwrite(str(out_path), crop)
        #parts.append(crop)
# Out:
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-0.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-1.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-2.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-3.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-4.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-5.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-6.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-7.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-8.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-9.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-10.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-11.tif
# /home/kaliev/Downloads/AerialImageDataset_crop/train/gt/vienna15-12.tif
# ...

# %%
_,axes=plt.subplots(4,4)
axes=axes.flatten()
for i in range(16):
    print(parts[i].shape)
    axes[i].imshow(parts[i])
    axes[i].axis('off')
plt.tight_layout()
# Out:
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)
# (1250, 1250, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# func to show image
def imshow(im,figsz=(12,12),**kwargs):
    plt.figure(figsize=figsz)
    plt.imshow(im,**kwargs)
    plt.axis('off')

imshow(img)
# Out:
# /home/kaliev/projects/comps/inria_aild/.env/lib/python3.6/site-packages/matplotlib/__init__.py:908: MatplotlibDeprecationWarning: The backend.qt4 rcParam was deprecated in version 2.2.  In order to force the use of a specific Qt binding, either import that binding first, or set the QT_API environment variable.
#   mplDeprecation)
# /home/kaliev/projects/comps/inria_aild/.env/lib/python3.6/site-packages/matplotlib/__init__.py:908: MatplotlibDeprecationWarning: The backend.qt4 rcParam was deprecated in version 2.2.  In order to force the use of a specific Qt binding, either import that binding first, or set the QT_API environment variable.
#   mplDeprecation)

# %%
w='chicago8'
img=f'/home/kaliev/Downloads/AerialImageDataset/train/images/{w}.tif'
gt=f'/home/kaliev/Downloads/AerialImageDataset/train/gt/{w}.tif'
img,gt=cv2.imread(img),cv2.imread(gt)[...,0]
img=img[:512,:512,::-1]
gt=gt[:512,:512]
img[:,:,0]=np.clip(img[:,:,0].astype(int)+gt/2,0,255).astype(np.uint8)
imshow(img)
