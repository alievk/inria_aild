# %%
import numpy as np
import torch
from models.summary import summary
from models.resnet import resnet34, resnet50, resnet101, resnet152
from models.inceptionresnetv2 import inceptionresnetv2
from models.unet import Resnet34_upsample

# %%
# model = Resnet34_upsample(2)
# model = resnet152()
model = inceptionresnetv2()

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(count_parameters(model) // 1000000, 'million parmas')
# Out:
# 15 million parmas

# %%
summary(model, input_size=(3, 512, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 256, 256]            9408
#        BatchNorm2d-2         [-1, 64, 256, 256]             128
#               ReLU-3         [-1, 64, 256, 256]               0
#          MaxPool2d-4         [-1, 64, 128, 128]               0
#             Conv2d-5         [-1, 64, 128, 128]            4096
#        BatchNorm2d-6         [-1, 64, 128, 128]             128
#               ReLU-7         [-1, 64, 128, 128]               0
#             Conv2d-8         [-1, 64, 128, 128]           36864
#        BatchNorm2d-9         [-1, 64, 128, 128]             128
#              ReLU-10         [-1, 64, 128, 128]               0
#            Conv2d-11        [-1, 256, 128, 128]           16384
#       BatchNorm2d-12        [-1, 256, 128, 128]             512
#            Conv2d-13        [-1, 256, 128, 128]           16384
# ...
